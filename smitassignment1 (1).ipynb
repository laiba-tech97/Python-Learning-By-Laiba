# %%
name="Laiba"
age=20
print(f"I am {name} i am {age} year old")
# Out:
# I am Laiba i am 20 year old

# %%
city="Karachi"
print("welcome to", city)
# Out:
# welcome to Karachi

# %%
a=5
b=3
print("The sum of two numbers=", a+b)
print("The difference of two numbers=", a-b)
print("The product of two numbers=", a*b)
print("The quotient of two numbers=", a%b)
print("The division of two numbers=", a/b)
# Out:
# The sum of two numbers= 8
# The difference of two numbers= 2
# The product of two numbers= 15
# The quotient of two numbers= 2
# The division of two numbers= 1.6666666666666667

# %%
1variable="Laiba" #illegal name because variable can't start with a number
variable1="Sara"   #legal name

# %%
pencils_3=10
pens_2=20
total=pencils_3 + pens_2
print(total)
# Out:
# 30

# %%
print(55%6)
# Out:
# 1

# %%
num=int(input("Enter a number:"))
square=num**2
print("Square of no= ",square)
cube=num**3
print("cube of no= ",cube)
# Out:
# Enter a number:7
# Square of no=  49
# cube of no=  343

# %%
count=10
count+=2
print(count)
count-=1
print(count)
# Out:
# 12
# 11

# %%
print(10+5*2)  #before ans=20
print((10+5)*2)  #ans=30
# Out:
# 20
# 30

# %%
math_marks=85
science_marks=90
print(f"All scored {math_marks} marks in Math and {science_marks} in Science")
# Out:
# All scored 85 marks in Math and 90 in Science

# %%
name=input("Enter your name:")
color=input("Enter your favourite color")
print(f"{name} loves the color {color}")
# Out:
# Enter your name:laiba
# Enter your favourite colorblack
# laiba loves the color black

# %%
first_name="Sara"
last_name="Khan"
print(first_name,last_name)
# Out:
# Sara Khan

# %%
marks=72
if marks>=50 :
  print("Congrats...You pass the exam")
else :
  print("Sad...You fail the exam")
# Out:
# Congrats...You pass the exam

# %%
marks=int(input("Enter your marks:"))
if marks>=90 :
  grade="A+"
elif marks>=80 :
  grade="A"
elif marks>=70 :
  grade="B"
elif marks>=60 :
  grade="C"
else :
  grade="F"
print(grade)
# Out:
# Enter your marks:67
# B

# %%
num=float(input("Enter a number:"))
if num%3==0 and num%5==0 :
  print("Yes..Number is divisible by both 3 and 5")
else :
  print("No..Number is not divisible by both 3 and 5")
# Out:
# Enter a number:15
# Yes..Number is divisible by both 3 and 5

# %%
age1=int(input("Enter age of 1st person:"))
age2=int(input("Enter age of 2nd person:"))
if age1>age2 :
  print("Older")
elif age1<age2 :
  print("Younger")
else :
  print("Same age")
# Out:
# Enter age of 1st person:47
# Enter age of 2nd person:23
# Older

# %%
num=float(input("Enter a number"))
if num%2==0 :
  print("Even number")
else :
  print("Odd number")
# Out:
# Enter a number62
# Even number

# %%
num=float(input("Enter a number"))
if num>=10 and num<=50 and num%5==0 :
  print("Yes.. number is between 10 and 50 and multiple of 5")
else :
  print("Condition not statisfied")
# Out:
# Enter a number58
# Condition not statisfied

# %%
username=input("Enter a username:")
if len(username)>5 and " " not in username :
  print("Valid")
else :
  print("Invalid")
# Out:
# Enter a username:Abubakkar
# Valid

# %%
math=float(input("Enter your math marks:"))
science=float(input("Enter your science marks:"))
if math>50 and science>50 :
  print("Passed Both")
elif math>50 or science>50 :
  print("Passed One")
else :
  print("Failed Both")
# Out:
# Enter your math marks:67
# Enter your science marks:81
# Passed Both
